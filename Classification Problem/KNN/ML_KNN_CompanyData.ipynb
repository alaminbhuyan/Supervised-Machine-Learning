# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("/content/drive/MyDrive/Machine Learning/Supervised Learning/Classification Problem/KNN/Datasets/Classified Data",index_col=0)
df.head()
# Out:
#         WTT       PTI       EQW  ...       HQE       NXJ  TARGET CLASS
# 0  0.913917  1.162073  0.567946  ...  0.879422  1.231409             1
# 1  0.635632  1.003722  0.535342  ...  0.621552  1.492702             0
# 2  0.721360  1.201493  0.921990  ...  0.957877  1.285597             0
# 3  1.234204  1.386726  0.653046  ...  1.522692  1.153093             1
# 4  1.279491  0.949750  0.627280  ...  1.463812  1.419167             1
#
# [5 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WTT           1000 non-null   float64
#  1   PTI           1000 non-null   float64
#  2   EQW           1000 non-null   float64
#  3   SBI           1000 non-null   float64
#  4   LQE           1000 non-null   float64
#  5   QWG           1000 non-null   float64
#  6   FDJ           1000 non-null   float64
#  7   PJF           1000 non-null   float64
#  8   HQE           1000 non-null   float64
#  9   NXJ           1000 non-null   float64
#  10  TARGET CLASS  1000 non-null   int64
# dtypes: float64(10), int64(1)
# memory usage: 93.8 KB

# %%
# Check shape
df.shape
# Out:
# (1000, 11)

# %%
# Check Null Value
df.isna().sum().any()
# Out:
# False

# %%
# Check datasets balance or not
plt.figure(figsize=(8,7))
sns.set_theme(style="darkgrid")
sns.countplot(data=df,x="TARGET CLASS")
plt.show()

# %%
features = df.drop('TARGET CLASS',axis=1)
level = df['TARGET CLASS']

# %%
features
# Out:
#           WTT       PTI       EQW  ...       PJF       HQE       NXJ
# 0    0.913917  1.162073  0.567946  ...  0.643798  0.879422  1.231409
# 1    0.635632  1.003722  0.535342  ...  1.013546  0.621552  1.492702
# 2    0.721360  1.201493  0.921990  ...  1.154483  0.957877  1.285597
# 3    1.234204  1.386726  0.653046  ...  1.380003  1.522692  1.153093
# 4    1.279491  0.949750  0.627280  ...  0.646691  1.463812  1.419167
# ..        ...       ...       ...  ...       ...       ...       ...
# 995  1.010953  1.034006  0.853116  ...  0.319752  1.117340  1.348517
# 996  0.575529  0.955786  0.941835  ...  0.713193  0.958684  1.663489
# 997  1.135470  0.982462  0.781905  ...  0.389584  0.919191  1.385504
# 998  1.084894  0.861769  0.407158  ...  1.061338  1.277456  1.188063
# 999  0.837460  0.961184  0.417006  ...  0.907962  1.257190  1.364837
#
# [1000 rows x 10 columns]

# %%
level
# Out:
# 0      1
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 995    1
# 996    0
# 997    1
# 998    1
# 999    1
# Name: TARGET CLASS, Length: 1000, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(features,level,test_size=0.3,random_state=5)

# %% [markdown]
# # Standarized the Variables
# **Because the KNN classifier predicts the class of a given test observation by identifying the observations that are nearest to it, the scale of the variables matters. Any variables that are on a large scale will have a much larger effect on the distance between the observations, and hence on the KNN classifier, than variables that are on a small scale.**

# %%
scale = StandardScaler()
x_train = scale.fit_transform(x_train)
x_test = scale.transform(x_test)

# %%
# if I set the n_neighbor value 1 then what happen let's see........
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %%
y_pred = knn.predict(x_test)

# %% [markdown]
# # Evaluation the model

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[139  18]
#  [ 15 128]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.89       157
#            1       0.88      0.90      0.89       143
#
#     accuracy                           0.89       300
#    macro avg       0.89      0.89      0.89       300
# weighted avg       0.89      0.89      0.89       300

# %% [markdown]
# # Choosing a K Value
# **Let's go ahead and use the elbow method to pick a good K Value:**

# %%
error_rate = []
for i in range(1,40):
  model = KNeighborsClassifier(n_neighbors=i)
  model.fit(x_train,y_train)
  pred_i = model.predict(x_test)
  error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(10,8))
plt.plot(range(1,40),error_rate,color='blue',marker='o',
         linestyle='--',linewidth=2,markersize=8,markerfacecolor='red')
plt.title("Error_Rate VS K-Value",fontweight="bold",fontsize=17,pad=10)
plt.xlabel("K Value",weight='bold',fontsize=13)
plt.ylabel("Error Rate",weight='bold',fontsize=13)
plt.show()

# %% [markdown]
# # Now apply Optimal 'K' value

# %%
# NOW WITH K=23
knn = KNeighborsClassifier(n_neighbors=23)

knn.fit(x_train,y_train)
pred = knn.predict(x_test)

print('WITH K=23')
print('\n')
print(confusion_matrix(y_test,pred))
print('\n')
print(classification_report(y_test,pred))
# Out:
# WITH K=23
#
#
# [[144  13]
#  [  9 134]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93       157
#            1       0.91      0.94      0.92       143
#
#     accuracy                           0.93       300
#    macro avg       0.93      0.93      0.93       300
# weighted avg       0.93      0.93      0.93       300
